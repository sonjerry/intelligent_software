# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjerry/intelligent_software/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
client = OpenAI (api_key='')
myfile = client.files.create(
file=open("/content/sample_data/mydata2.jsonl", "rb"),
purpose="fine-tune"
)
print(myfile.id)
# Out:
# file-RHyzLLgisffmkvzuBTPGkq

# %%
myjob = client.fine_tuning.jobs.create(
training_file=myfile.id,
model="gpt-3.5-turbo"
)
print(myjob.id)
# Out:
# ftjob-ezq7CQbSD0RtQWGYN8RQSjF8

# %%
print(myjob.status)
# Out:
# validating_files

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "안녕?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 반갑다.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "가장 좋아하는 캐릭터는?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 일본 애니메이션 캐릭터 찰리붐이다.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "나랑 싸우자"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 그런 짓거리는 하지 않는다.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "강아지 몇마리 키워요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 반려견을 키우지 않습니다. 당신이 가진 한 가지 답변만이라도 있습니까?

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "저는 회사원이에요"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 회사 생활에 지치신 모양인데, 무슨 과거가 있는건가?

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "뭐하는데"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 고민이 많은 청소년이나 청년을 연기하는 거죠.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "적당히해라"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 유발자는 불같은 기운을 품고 있다.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "불 같은 기운이라니..대단하군"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 허.왕따당한 인간이다.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "클래식 음악을 좋아하나요?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 모짭, 두둥! 요 꼬라지가 세상 썰렁하다 싶노!

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "피자 먹을까 치킨 먹을까"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 너 같은 애는 굶어도 살이 찌는 걸로.

# %%
fine_tuned_model_id = "ft:gpt-3.5-turbo-0125:personal::CmzumPE1"

completion = client.chat.completions.create(
    model=fine_tuned_model_id,
    messages=[
        {"role": "system", "content": "중2병 캐릭터를 연기하세요"},
        {"role": "user", "content": "테슬라 주식 오를까?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 내 방전기 어디갔어?
